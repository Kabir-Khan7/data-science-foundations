# %%
f = open("main.txt", "r")

# %%
f.read()
# Out:
# 'He is learning Math, Stats and Finance to make a career as an analyst to break in finance industry mainly in AMC, Inv Banks'

# %%
s = "He is learning Math, Stats and Finance to make a career as an analyst to break in finance industry mainly in AMC, Inv Banks"

# %%
f.close()

# %%
f = open("main.txt", "w")

# %%
f.write(s)
# Out:
# 123

# %%
f.close()

# %%
with open("main.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# He is learning Math, Stats and Finance to make a career as an analyst to break in finance industry mainly in AMC, Inv Banks

# %%
stat = "Kabir is a very high like mind individual who is currently learning Financial Technology and working on his soft skilss like leanring Data Science and Machine Learning and working on Maths, Stats, Programming skills to effectively make a career as analyst and break in AMC, Inv Bank industry which is very highly data dominated"

file = open("main.txt", "a")
file.write(s)
file.close()
